# %% [markdown]
# <a href="https://colab.research.google.com/github/Adersoncc/acc/blob/main/vamos_nessa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
uri = "https://raw.githubusercontent.com/alura-cursos/introducao-a-data-science/master/aula4.1/movies.csv"
filmes = pd.read_csv(uri)     # dataframe
filmes.head(10)
# Out:
#    movieId  ...                                       genres
# 0        1  ...  Adventure|Animation|Children|Comedy|Fantasy
# 1        2  ...                   Adventure|Children|Fantasy
# 2        3  ...                               Comedy|Romance
# 3        4  ...                         Comedy|Drama|Romance
# 4        5  ...                                       Comedy
# 5        6  ...                        Action|Crime|Thriller
# 6        7  ...                               Comedy|Romance
# 7        8  ...                           Adventure|Children
# 8        9  ...                                       Action
# 9       10  ...                    Action|Adventure|Thriller
#
# [10 rows x 3 columns]

# %%
filmes.columns = "filmesId","tituloId","genero"

# %%
filmes.head(6)
# Out:
#    filmesId  ...                                       genero
# 0         1  ...  Adventure|Animation|Children|Comedy|Fantasy
# 1         2  ...                   Adventure|Children|Fantasy
# 2         3  ...                               Comedy|Romance
# 3         4  ...                         Comedy|Drama|Romance
# 4         5  ...                                       Comedy
# 5         6  ...                        Action|Crime|Thriller
#
# [6 rows x 3 columns]

# %%
uri = "https://raw.githubusercontent.com/alura-cursos/introducao-a-data-science/master/aula1.2/ratings.csv"
notas = pd.read_csv(uri)
notas.columns = "usuarioId","filmeId","notaId","momento"
notas.head(10)
# Out:
#    usuarioId  filmeId  notaId    momento
# 0          1        1     4.0  964982703
# 1          1        3     4.0  964981247
# 2          1        6     4.0  964982224
# 3          1       47     5.0  964983815
# 4          1       50     5.0  964982931
# 5          1       70     3.0  964982400
# 6          1      101     5.0  964980868
# 7          1      110     4.0  964982176
# 8          1      151     5.0  964984041
# 9          1      157     5.0  964984100

# %%
notas.notaId.head()  #serie
# Out:
# 0    4.0
# 1    4.0
# 2    4.0
# 3    5.0
# 4    5.0
# Name: notaId, dtype: float64

# %%
notas.describe()
# Out:
#            usuarioId        filmeId         notaId       momento
# count  100836.000000  100836.000000  100836.000000  1.008360e+05
# mean      326.127564   19435.295718       3.501557  1.205946e+09
# std       182.618491   35530.987199       1.042529  2.162610e+08
# min         1.000000       1.000000       0.500000  8.281246e+08
# 25%       177.000000    1199.000000       3.000000  1.019124e+09
# 50%       325.000000    2991.000000       3.500000  1.186087e+09
# 75%       477.000000    8122.000000       4.000000  1.435994e+09
# max       610.000000  193609.000000       5.000000  1.537799e+09

# %%
notas.diff().head()
# Out:
#    usuarioId  filmeId  notaId  momento
# 0        NaN      NaN     NaN      NaN
# 1        0.0      2.0     0.0  -1456.0
# 2        0.0      3.0     0.0    977.0
# 3        0.0     41.0     1.0   1591.0
# 4        0.0      3.0     0.0   -884.0

# %%
notas["notaId"].unique()
# Out:
# array([4. , 5. , 3. , 2. , 1. , 4.5, 3.5, 2.5, 0.5, 1.5])

# %%
notas.notaId.plot(kind="hist")

# %%
sns.boxplot(notas.notaId)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(notas.notaId)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
notas.notaId.value_counts(  )
# Out:
# 4.0    26818
# 3.0    20047
# 5.0    13211
# 3.5    13136
# 4.5     8551
# 2.0     7551
# 2.5     5550
# 1.0     2811
# 1.5     1791
# 0.5     1370
# Name: notaId, dtype: int64

# %%
filmes.describe()
# Out:
#              movieId
# count    9742.000000
# mean    42200.353623
# std     52160.494854
# min         1.000000
# 25%      3248.250000
# 50%      7300.000000
# 75%     76232.000000
# max    193609.000000

# %%
filmes.filmesId.plot(kind="hist")

# %%
filmes = pd.read_csv(uri)
filmes.columns = "filmesId","titulo","genero"
filmes.head(10)
# Out:
#    filmesId  ...                                       genero
# 0         1  ...  Adventure|Animation|Children|Comedy|Fantasy
# 1         2  ...                   Adventure|Children|Fantasy
# 2         3  ...                               Comedy|Romance
# 3         4  ...                         Comedy|Drama|Romance
# 4         5  ...                                       Comedy
# 5         6  ...                        Action|Crime|Thriller
# 6         7  ...                               Comedy|Romance
# 7         8  ...                           Adventure|Children
# 8         9  ...                                       Action
# 9        10  ...                    Action|Adventure|Thriller
#
# [10 rows x 3 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-97-bf1527830a5b> in <module>()
# ----> 1 medias_por_filme = notas.groupby("filmesId" ).mean().nota
#       2 medias_por_filme.head(8)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6523             squeeze=squeeze,
#    6524             observed=observed,
# -> 6525             dropna=dropna,
#    6526         )
#    6527
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     531                 observed=observed,
#     532                 mutated=self.mutated,
# --> 533                 dropna=self.dropna,
#     534             )
#     535
#
# ...
